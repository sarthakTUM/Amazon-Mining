# %% [markdown]
# ### Tasks In The Notebook:

# %% [markdown]
# 1. Calculates the average rating given by each reviewer.
# 2. Calculates the number of reviews by each reviewer.
# 3. Converts date to YYYYMMDD format.
# 4. Sort the date in ascending order.
# 5. Gets the first date when the Reviewer first rated a product.
# 6. Merges previous data frames.
# 7. Calculate the helpfulness ration.
# 8. Weights the helpfulness ratio.
# 9. Merges the helpfulness ratio to get the final result.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import plotly.plotly as py
#py.set_credentials_file(username='raoshaheryarkhan', api_key='KswnKD2cSzUMp6zxf25p')
import plotly.figure_factory as ff
import math
from datetime import datetime
import sys
import os

# %%
project_path = "PycharmProjects/Amazon-Mining"
# make sure to use position 1
sys.path.insert(1, project_path)

# %%
os.chdir("/Users\RSK\PycharmProjects\Amazon-Mining")
from src.data.json_loader import JSONLoader

# %%
# file_path corresponds to the file of the .gz file which contains the JSON file. 
os.chdir("/Users\RSK")
file_path = 'Documents\DataMining/reviews_Electronics_5.json.gz'
loader = JSONLoader()

# %%
# data is a Pandas Dataframe object.
data = loader.load_data(file_path)

# %% [markdown]
# #### Data Has Been Loaded

# %% [markdown]
# ###### Calculating Avg rating given by each Reviewer.

# %%
meanReview = data[['reviewerID','overall']].groupby(['reviewerID'],as_index=False).mean()
meanReview = meanReview.rename(columns = {'overall':'Avgrating'})

# %% [markdown]
# ###### Calculating number of Reviews given by each reviewer and joining it with mean rating given by each reviewer.

# %%
reviewerCount = data[['reviewerID','asin']].groupby(['reviewerID'], as_index=False).count()
reviewerCount = reviewerCount.rename(columns = {'asin':'reviewCount'})
reviewer = pd.merge(reviewerCount, meanReview, on = "reviewerID")

# %% [markdown]
# ###### Below function converts the date in data to format of YYYYMMDD e.g., 20171101 . its 1st Nov 2017

# %%
def to_YYYYMMDD(row):   
    datetime_object = datetime.strptime(row['reviewTime'], '%m %d, %Y').date()
    return datetime.strftime(datetime_object, "%Y%m%d")

# %%
data['date(YYYYMMDD)'] = data.apply (lambda row: to_YYYYMMDD (row),axis=1)

# %% [markdown]
# ###### loading the interested columns into the other data frame for better processing

# %%
reviewerData = data[['reviewerID','reviewerName','date(YYYYMMDD)']].copy()

# %% [markdown]
# ###### Now sorting the values in ascending order on YYYYMMDD format.

# %%
reviewerData = reviewerData.groupby('reviewerID').apply(lambda x: x.sort_values('date(YYYYMMDD)'))

# %% [markdown]
# ###### Get the first record of each Employee. as now first record contains the date on which Reviewer first gave review

# %% [markdown]
# ###### These del reviewerID column is just to remove redundant column. which will cause issue when we reset index.

# %%
del reviewerData['reviewerID']
temp = reviewerData
temp = temp.groupby('reviewerID').head(1)

# %% [markdown]
# ###### level_1 was the column generated as a result of sorting and reset index. so getting rid of it

# %%
temp = temp.reset_index()
del temp['level_1']

# %% [markdown]
# ###### merging date wise result with previous data frame.

# %%
reviewer_df = pd.merge(temp, reviewer, on = "reviewerID")

# %% [markdown]
# ###### Aamna's code till next 4 cell

# %%
data['helpfulness_ratio']=(data['helpful'].str[0])/(data['helpful'].str[1])

# %% [markdown]
# ###### Code to extract helpful votes(num) and total votes(den)

# %%
help_df=pd.DataFrame(data['helpful'])
help_df['helpful']=help_df['helpful'].astype(str)
help_df['a'] = help_df['helpful'].apply(lambda x: x.split(',')[0])
help_df['b'] = help_df['helpful'].apply(lambda x: x.split(',')[1])
help_df['num']=help_df['a'].map(lambda x: x.lstrip('['))
help_df['deno']=help_df['b'].map(lambda x: x.rstrip(']'))
help_df['deno']=help_df['deno'].astype(int)
help_df['deno']=help_df['num'].astype(int)

# %% [markdown]
# ###### calculated mean of total votes(den) and divided each den with this mean to generate weights/scale Multiplied each helpfulness_ratio in the main dataframe called 'data' with this scale to get helpfulness score

# %%
mean=help_df['deno'].mean()
mean
help_df['scale']= help_df['deno']/mean
#help_df['final_ratio']= help_df['helpful_ratio']*help_df['scale']
help_df
#help_df['helpful_ratio']= help_df['num']/help_df['deno']
data['helpfulness_score']=data['helpfulness_ratio']*help_df['scale']

# %% [markdown]
# ###### Since this score has a wide range of values, I have normalized it to get the values bw 0 and 1

# %%
data['helpfulness_score']=(data['helpfulness_score']-data['helpfulness_score'].min())/(data['helpfulness_score'].max()-data['helpfulness_score'].min())

# %% [markdown]
# ###### Taking mean of all helfulness score per Reviewer.

# %%
meanHelpfulnessScore = data[['reviewerID','helpfulness_score']].groupby(['reviewerID'],as_index=False).mean()
meanHelpfulnessScore = meanHelpfulnessScore.rename(columns = {'helpfulness_score':'Avghelfulness'})

# %% [markdown]
# ###### Joining Helpfulness with the previous data frame to get our final data frame.

# %%
reviewer_df = pd.merge(reviewer_df, meanHelpfulnessScore, on = "reviewerID")

# %% [markdown]
# ###### The final result

# %%
reviewer_df
# Out:
#                    reviewerID                         reviewerName  \
# 0       A000715434M800HLCENK9                                   DP
# 1        A00101847G3FJTWYGNQA                           Cang Cheng
# 2       A00166281YWM98A3SVD55                             Band Mom
# 3       A0046696382DWIPVIWO0K  Fernando Molinas "Fernando Molinas"
# 4       A00472881KT6WR48K907X                       Matthew Wright
# 5       A00473363TJ8YSZ3YAGG9                        Thomas Rogers
# 6       A005721627VX5W2COKKK2                          Purav Patel
# 7       A00700212KB3K0MVESPIY                       sandra conklin
# 8       A007780739H92ZWKGVWGJ                         Ron Burnette
# 9       A00814373OZEDXYMXP04T                       Nathan Johnson
# 10      A01036691ZFOFCXBLP2D1                               pcfixr
# 11       A0103849GBVWICKXD4T6                                   Te
# 12       A0104775CQOXJTV4OH68                               Daniel
# 13       A0110255Y4ER0RTKEKXS                               Jordan
# 14      A013908612VUH8DIZ15HB                                mreed
# 15      A0154198260VIT02KU4BW                               Thomas
# 16      A017375010TRKBWQT4FT7                   Logan Drake Pulley
# 17       A0188546ES14USV0TFXO                         Alex Sharifi
# 18       A0191512Q2Z9IPUAE2RZ                                slpip
# 19      A01959122DLCCNPPR0BPO                               GOLDIE
# 20      A021662527TDMT16ZZPQJ                              Martins
# 21      A024565715EP46DCTABI4                               Carlos
# 22       A0251761JI35FM4C8VK2                                Lavon
# 23      A0260105268IXGY2H11N2                                 Zack
# 24       A0266076X6KPZ6CCHGVS                      Tyrel "Brandon"
# 25      A02712303HM5RXRLNJUB7                                 Adam
# 26      A027717628HVUA4XE5VL3                          Christopher
# 27       A0279100VZXR9A2495P4                              Roberto
# 28      A02812102TXIQ71LMSW46                                  MCS
# 29       A0284208PB0CNSHI1OC6                          aaron burns
# ...                       ...                                  ...
# 192373          AZZA7IQWTXCH3                 netzotic "Tech Head"
# 192374          AZZB1GSHMEBUS        Eugenia Anton "Eugenia Anton"
# 192375          AZZB7QPNM6ENC                        Teddy Striker
# 192376          AZZBB05CJFP35                  larryhat "larryhat"
# 192377          AZZCN2ZC5QM8L             Holly Ragland "raglnd35"
# 192378          AZZEHNTA5QFL0                               BeeGee
# 192379          AZZFRY8O72WH8                            V. Walton
# 192380          AZZGB87A5N9QI                        K. B. Stroman
# 192381          AZZIFAMCVA0YJ                           yk michael
# 192382          AZZJZQGBP0GNE           Amazon Customer "Peter C."
# 192383          AZZLZUR5X9GYE                             Waukomis
# 192384          AZZM0MGLACRHJ                           ManhassetZ
# 192385          AZZMHJOV6T15J                                 PTR2
# 192386          AZZNHVT9AH73R                             Lazer G.
# 192387          AZZNK89PXD006                                Etude
# 192388          AZZOQCD4U42P0               Frank J. Martinez "FJ"
# 192389          AZZPC198R5R4U                           HappyRider
# 192390          AZZR8DUVE5L8O                                 T.Q.
# 192391          AZZRPY6IJC7SP                                  NaN
# 192392          AZZRTVJUYL0YC                              Skeptic
# 192393          AZZS13C32YSPH                              BadBrad
# 192394          AZZTC2OYVNE2Q                               Wouter
# 192395          AZZTCG8URXK9W                           S. Seubert
# 192396          AZZTOUKVTUMVM                            DGBradley
# 192397          AZZUDVKC0E2XU                        Barry G. Wick
# 192398          AZZV2NAQL8KHQ                                  kim
# 192399          AZZVLOF3WKLFW                          P. Privette
# 192400          AZZVYHVJ8BDUZ                        Mike Davinroy
# 192401          AZZX23UGJGKTT                               Jim D.
# 192402          AZZYW4YOE1B6E                              tmybrgr
#
#        date(YYYYMMDD)  reviewCount  Avgrating  Avghelfulness
# 0            20140519            5   3.200000       0.000033
# 1            20130919            6   4.666667       0.000025
# 2            20130417            5   4.800000       0.000200
# 3            20130621            5   4.200000       0.000025
# 4            20130128            7   4.571429       0.000067
# 5            20130708            9   3.666667            NaN
# 6            20121227            7   4.714286       0.000067
# 7            20131125            6   5.000000       0.000033
# 8            20130509            6   4.666667            NaN
# 9            20130705            6   4.833333       0.000033
# 10           20121112            5   4.600000       0.000008
# 11           20130301            6   4.833333       0.000339
# 12           20131228            5   3.200000       0.000000
# 13           20140519            9   5.000000       0.000017
# 14           20131004            7   4.857143       0.000033
# 15           20130721            5   5.000000            NaN
# 16           20121120            5   5.000000       0.000017
# 17           20130131            7   3.714286       0.000021
# 18           20130706            5   3.200000       0.000051
# 19           20130115            5   5.000000       0.000000
# 20           20140325            5   3.400000            NaN
# 21           20130219            5   3.600000       0.000033
# 22           20130204           11   5.000000       0.000037
# 23           20130227            7   5.000000            NaN
# 24           20121123            7   5.000000       0.000112
# 25           20130530           10   4.800000       0.000050
# 26           20130420            5   4.200000       0.000055
# 27           20121116            6   5.000000       0.000042
# 28           20130118            5   3.400000       0.000113
# 29           20130201           18   4.111111       0.000025
# ...               ...          ...        ...            ...
# 192373       20060507            5   2.800000       0.000397
# 192374       20090818            6   2.166667       0.000069
# 192375       20070103            9   3.111111       0.000027
# 192376       20050911           12   3.166667       0.000184
# 192377       20100222            5   4.800000       0.000067
# 192378       20130124            9   4.555556       0.000033
# 192379       20130722            5   2.400000       0.000035
# 192380       20090805           10   4.400000       0.000071
# 192381       20110319            7   3.857143       0.000046
# 192382       20060705            5   4.000000       0.000047
# 192383       20120501           15   4.933333       0.000075
# 192384       20070619            7   4.428571       0.000054
# 192385       20121120            5   4.200000       0.000102
# 192386       20140120            8   4.000000            NaN
# 192387       20100423           15   3.800000       0.000142
# 192388       20070126            6   4.833333       0.000300
# 192389       20121009            6   5.000000       0.000046
# 192390       20070706            7   4.142857       0.000696
# 192391       20120205           10   4.200000            NaN
# 192392       20070109            6   3.166667       0.000089
# 192393       20080405            6   4.833333       0.000039
# 192394       20120715           17   4.529412       0.000007
# 192395       20110130            8   4.500000       0.000033
# 192396       20130806            5   4.200000            NaN
# 192397       20130403            7   4.285714       0.000033
# 192398       20130222            9   4.222222       0.000033
# 192399       20090406           12   3.500000       0.000048
# 192400       20121127            7   4.714286       0.000033
# 192401       20121021           22   4.545455       0.000189
# 192402       20091229           32   4.468750       0.000070
#
# [192403 rows x 6 columns]
