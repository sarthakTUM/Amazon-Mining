# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import plotly.plotly as py
#py.set_credentials_file(username='raoshaheryarkhan', api_key='KswnKD2cSzUMp6zxf25p')
import plotly.figure_factory as ff
import math
from datetime import datetime
import sys
import os

# %%
import sys
project_path = "/home/aamna/Documents/apc/Amazon-Mining"
# make sure to use position 1
sys.path.insert(1, project_path)

# %%
from src.data.json_loader import JSONLoader

# %%
# file_path corresponds to the file of the .gz file which contains the JSON file. 
file_path = '/home/aamna/Documents/apc/reviews_Electronics_5.json.gz'
metadata_path='/home/aamna/Documents/apc/meta_Electronics.json.gz'
loader = JSONLoader()

# %%
data = loader.load_data(file_path)
#product=loader.load_data(metadata_path)

# %%
w=product.loc[product['asin']=B0074BW614]
# Out:
#   File "<ipython-input-78-c13307ccae93>", line 1
#     w=product.loc[product['asin']=B0074BW614]
#                                  ^
# SyntaxError: invalid syntax

# %%
df1 = data[['reviewerID','overall','asin']].copy()

# %%
df2 = product[['asin','price','brand']].copy()

# %%
df=pd.merge(df1,df2  ,on='asin', how='left')

# %%
df

# %%
productrating = df[['asin','brand','overall']].groupby(['asin'],as_index=False).mean()
productrating = productrating.rename(columns = {'overall':'product_rating'})

# %%
productrating=pd.merge(productrating,df2  ,on='asin', how='left')

# %%
productrating.to_csv('product.csv',index=False)

# %%
productrating

# %%
productrating['price'].corr(productrating['product_rating'])

# %%
data.reviewTime = data.reviewTime .astype(str)
data['Year']=(data['reviewTime'].str[-4:])
data['Month']=(data['reviewTime'].str[0:2])
data['Day']=(data['reviewTime'].str[2:5])
data['Day']=data['Day'].str.replace(',','')
data['helpfulness_ratio']=(data['helpful'].str[0])/(data['helpful'].str[1])
data['review_length']=data['reviewText'].str.len()

# %%
def word_count(row):
    str=row['reviewText']
    tokens=str.split()
    n_tokens=len(tokens)
    return n_tokens

# %%
data['Wordcount'] = data.apply(lambda row :word_count(row), axis=1)

# %%
def f(row):
    if row['overall'] == 3.0:
        val = 'Neutral'
    elif row['overall'] > 3.0:
        val = 'Positive'
    else:
        val = 'Negative'
    return val

# %%
data['Reviewcategory'] = data.apply(f, axis=1)

# %%
data
# Out:
#              reviewerID                                         reviewText  \
# 0         AO94DHGC771SJ  We got this GPS for my husband who is an (OTR)...
# 1         AMO214LNFCEI4  I'm a professional OTR truck driver, and I bou...
# 2        A3N7T0DY83Y4IG  Well, what can I say.  I've had this unit in m...
# 3        A1H8PY3QHMQQA0  Not going to write a long review, even thought...
# 4        A24EV6RXELQZ63  I've had mine for a year and here's what we go...
# 5        A2JXAZZI9PHK9Z  I am using this with a Nook HD+. It works as d...
# 6        A2P5U7BDKKT7FW  The cable is very wobbly and sometimes disconn...
# 7         AAZ084UMH8VZ2  This adaptor is real easy to setup and use rig...
# 8         AEZ3CR6BKIROJ  This adapter easily connects my Nook HD 7&#34;...
# 9        A3BY5KCNQZXV5U  This product really works great but I found th...
# 10        A7S2B0I67WNWB  This item is just as was described in the orig...
# 1689182           5119        900       Positive
# 1689183           1095        194       Positive
# 1689184           4227        685       Positive
# 1689185           2290        400       Positive
# 1689186           1900        324       Positive
# 1689187           2451        454       Positive
#
# [1689188 rows x 13 columns]

# %%
data['helpful']=data['helpful'].astype(str)
data['a'] = data['helpful'].apply(lambda x: x.split(',')[0])
data['b'] = data['helpful'].apply(lambda x: x.split(',')[1])
data['num']=data['a'].map(lambda x: x.lstrip('['))
data['deno']=data['b'].map(lambda x: x.rstrip(']'))
data['helpful_votes']=data['num'].astype(int)
data['total_votes']=data['deno'].astype(int)
data['unhelpful_votes']=data['total_votes'] - data['helpful_votes']
data['overall_helpfulness']=data['helpful_votes'] - data['unhelpful_votes']

# %%
data['overall_helpfulness']=(data['overall_helpfulness'] - data['overall_helpfulness'].min())/(data['overall_helpfulness'].max() -data['overall_helpfulness'].min())

# %%
data.head()

# %%
df_r = data[['Wordcount','overall','helpfulness_ratio','asin','overall_helpfulness']].copy()

# %%
df_p= product[['price','asin']].copy()

# %%
out=df=pd.merge(df_r,df_p  ,on='asin', how='left')

# %%
out.to_csv('product.csv',index=False)

# %%
data=data.drop('a', 1)
data=data.drop('b', 1)
data=data.drop('num', 1)
data=data.drop('deno', 1)

# %%
data=data.drop('reviewerName', 1)
data=data.drop('helpful', 1)
data=data.drop('unixReviewTime', 1)

# %%
data.head()

# %%
test=data[['Wordcount','overall_helpfulness','overall','helpfulness_ratio']].copy()

# %%
data=data.test('a', 1)
data=data.drop('b', 1)
data=data.drop('num', 1)
data=data.drop('deno', 1)

# %%
test['Wordcount'].corr(test['overall_helpfulness'])

# %%
test['overall'].corr(test['helpfulness_ratio'])

# %%
test.to_csv('test.csv',index=False)

# %%
a = data[['Wordcount','asin']].copy()

# %%
b = product[['price','asin']].copy()

# %%
a=pd.merge(a,b  ,on='asin', how='left')

# %%
a

# %%
a['Wordcount'].corr(a['price'])

# %%
a.to_csv('price.csv',index=False)

# %%
meanReview = data[['reviewerID','overall']].groupby(['reviewerID'],as_index=False).mean()
meanReview = meanReview.rename(columns = {'overall':'Avgrating'})

# %%
reviewerCount = data[['reviewerID','asin']].groupby(['reviewerID'], as_index=False).count()
reviewerCount = reviewerCount.rename(columns = {'asin':'reviewCount'})
reviewer = pd.merge(reviewerCount, meanReview, on = "reviewerID")

# %%
meanwordCount = data[['reviewerID','Wordcount']].groupby(['reviewerID'], as_index=False).mean()
meanwordCount = meanwordCount.rename(columns = {'Wordcount':'avg_wordcount'})
reviewer = pd.merge(reviewer, meanwordCount, on = "reviewerID")

# %%
def to_YYYYMMDD(row):   
    datetime_object = datetime.strptime(row['reviewTime'], '%m %d, %Y').date()
    return datetime.strftime(datetime_object, "%Y%m%d")

# %%
data['date(YYYYMMDD)'] = data.apply (lambda row: to_YYYYMMDD (row),axis=1)

# %%
reviewerData = data[['reviewerID','reviewerName','date(YYYYMMDD)']].copy()
reviewerData
# Out:
#              reviewerID                                      reviewerName  \
# 0         AO94DHGC771SJ                                           amazdnu
# 1689178  A26VF18X91983P                                           Richard
# 1689179  A2XRMQA6PJ5ZJ8                               Roger J. Buffington
# 1689180  A3A4ZAIBQWKOZS                                  Stephen M. Lerch
# 1689181   AOVTLYTHVDNUX                    Tradecraft "Live by the Sword"
# 1689182   A1AJVEBU3Y8GB                                     Will_R "Will"
# 1689183  A34BZM6S9L7QI4                       Candy Cane "Is it just me?"
# 1689184  A1G650TTTHEAL5                   Charles Spanky "Zumina Reviews"
# 1689185  A25C2M3QF9G7OQ                                            Comdet
# 1689186   A1E1LEVQ9VQNK                                       J. Chambers
# 1689187  A2NYK9KWFMJV4Y                       Mike Tarrani "Jazz Drummer"
#
#         date(YYYYMMDD)
# 0             20130602
# 1             20101125
# 2             20100909
# 3             20101124
# 4             20110929
# 5             20140103
# 6             20140427
# 7             20140504
# 8             20140711
# 9             20140120
# 10            20140416
# 11            20140505
# 12            20130624
# 13            20130525
# 14            20140309
# 15            20130831
# 16            20130918
# 17            20130627
# 18            20140712
# 19            20130430
# 20            20111216
# 21            20131123
# 22            20100830
# 23            20130512
# 24            20140107
# 25            20130518
# 26            20130221
# 27            20120317
# 28            20140416
# 29            20130109
# ...                ...
# 1689158       20140717
# 1689159       20140627
# 1689160       20140627
# 1689161       20140713
# 1689162       20140711
# 1689163       20140705
# 1689164       20140714
# 1689165       20140713
# 1689166       20140710
# 1689167       20140711
# 1689168       20140708
# 1689169       20140706
# 1689170       20140706
# 1689171       20140721
# 1689172       20140710
# 1689173       20140717
# 1689174       20140719
# 1689175       20140715
# 1689176       20140707
# 1689177       20140716
# 1689178       20140722
# 1689179       20140710
# 1689180       20140707
# 1689181       20140714
# 1689182       20140716
# 1689183       20140717
# 1689184       20140715
# 1689185       20140717
# 1689186       20140718
# 1689187       20140713
#
# [1689188 rows x 3 columns]

# %%
reviewerData = reviewerData.groupby('reviewerID').apply(lambda x: x.sort_values('date(YYYYMMDD)'))

# %%
del reviewerData['reviewerID']
temp = reviewerData
temp = temp.groupby('reviewerID').head(1)

# %%
temp = temp.reset_index()
del temp['level_1']

# %%
reviewer_df = pd.merge(temp, reviewer, on = "reviewerID")

# %%
sum_helpful_votes = data[['reviewerID','helpful_votes']].groupby(['reviewerID'],as_index=False).sum()
sum_helpful_votes = sum_helpful_votes .rename(columns = {'helpful_votes':'sum_helpful_votes'})

# %%
sum_unhelpful_votes = data[['reviewerID','unhelpful_votes']].groupby(['reviewerID'],as_index=False).sum()
sum_unhelpful_votes = sum_unhelpful_votes .rename(columns = {'unhelpful_votes':'sum_unhelpful_votes'})

# %%
reviewer_df = pd.merge(reviewer_df, sum_helpful_votes, on = "reviewerID")

# %%
reviewer_df = pd.merge(reviewer_df, sum_unhelpful_votes, on = "reviewerID")

# %%
reviewer_df['total_votes']=reviewer_df['sum_helpful_votes'] + reviewer_df['sum_unhelpful_votes']

# %%
reviewer_df['overall_helpfulness']=reviewer_df['sum_helpful_votes'] - reviewer_df['sum_unhelpful_votes']

# %%
reviewer_df=reviewer_df.drop('total_votes', 1)
reviewer_df
# Out:
#                    reviewerID                         reviewerName  \
# 0       A000715434M800HLCENK9                                   DP
# 1        A00101847G3FJTWYGNQA                           Cang Cheng
# 2       A00166281YWM98A3SVD55                             Band Mom
# 3       A0046696382DWIPVIWO0K  Fernando Molinas "Fernando Molinas"
# 4       A00472881KT6WR48K907X                       Matthew Wright
# 5       A00473363TJ8YSZ3YAGG9                        Thomas Rogers
# 6       A005721627VX5W2COKKK2                          Purav Patel
# 7       A00700212KB3K0MVESPIY                       sandra conklin
# 8       A007780739H92ZWKGVWGJ                         Ron Burnette
# 9       A00814373OZEDXYMXP04T                       Nathan Johnson
# 10      A01036691ZFOFCXBLP2D1                               pcfixr
# 11       A0103849GBVWICKXD4T6                                   Te
# 12       A0104775CQOXJTV4OH68                               Daniel
# 13       A0110255Y4ER0RTKEKXS                               Jordan
# 14      A013908612VUH8DIZ15HB                                mreed
# 15      A0154198260VIT02KU4BW                               Thomas
# 16      A017375010TRKBWQT4FT7                   Logan Drake Pulley
# 17       A0188546ES14USV0TFXO                         Alex Sharifi
# 18       A0191512Q2Z9IPUAE2RZ                                slpip
# 19      A01959122DLCCNPPR0BPO                               GOLDIE
# 20      A021662527TDMT16ZZPQJ                              Martins
# 21      A024565715EP46DCTABI4                               Carlos
# 22       A0251761JI35FM4C8VK2                                Lavon
# 23      A0260105268IXGY2H11N2                                 Zack
# 24       A0266076X6KPZ6CCHGVS                      Tyrel "Brandon"
# 25      A02712303HM5RXRLNJUB7                                 Adam
# 26      A027717628HVUA4XE5VL3                          Christopher
# 27       A0279100VZXR9A2495P4                              Roberto
# 28      A02812102TXIQ71LMSW46                                  MCS
# 29       A0284208PB0CNSHI1OC6                          aaron burns
# ...                       ...                                  ...
# 192373          AZZA7IQWTXCH3                 netzotic "Tech Head"
# 192374          AZZB1GSHMEBUS        Eugenia Anton "Eugenia Anton"
# 192375          AZZB7QPNM6ENC                        Teddy Striker
# 192376          AZZBB05CJFP35                  larryhat "larryhat"
# 192377          AZZCN2ZC5QM8L             Holly Ragland "raglnd35"
# 192378          AZZEHNTA5QFL0                               BeeGee
# 192379          AZZFRY8O72WH8                            V. Walton
# 192380          AZZGB87A5N9QI                        K. B. Stroman
# 192381          AZZIFAMCVA0YJ                           yk michael
# 192382          AZZJZQGBP0GNE           Amazon Customer "Peter C."
# 192383          AZZLZUR5X9GYE                             Waukomis
# 192384          AZZM0MGLACRHJ                           ManhassetZ
# 192385          AZZMHJOV6T15J                                 PTR2
# 192386          AZZNHVT9AH73R                             Lazer G.
# 192387          AZZNK89PXD006                                Etude
# 192388          AZZOQCD4U42P0               Frank J. Martinez "FJ"
# 192389          AZZPC198R5R4U                           HappyRider
# 192390          AZZR8DUVE5L8O                                 T.Q.
# 192391          AZZRPY6IJC7SP                                  NaN
# 192392          AZZRTVJUYL0YC                              Skeptic
# 192393          AZZS13C32YSPH                              BadBrad
# 192394          AZZTC2OYVNE2Q                               Wouter
#
#         sum_helpful_votes  sum_unhelpful_votes  overall_helpfulness
# 0                       1                    0                    1
# 1                       2                    1                    1
# 2                       6                    0                    6
# 3                       2                    1                    1
# 4                       4                    0                    4
# 5                       0                    0                    0
# 6                       2                    0                    2
# 7                       1                    0                    1
# 8                       0                    0                    0
# 9                       1                    0                    1
# 10                      1                    2                   -1
# 11                     23                    3                   20
# 12                      0                    1                   -1
# 13                      1                    1                    0
# 14                      2                    0                    2
# 15                      0                    0                    0
# 16                      1                    1                    0
# 17                      3                    2                    1
# 18                      4                   13                   -9
# 19                      0                    2                   -2
# 20                      0                    0                    0
# 21                      1                    0                    1
# 22                      4                    2                    2
# 23                      0                    0                    0
# 24                     11                    1                   10
# 25                      3                    0                    3
# 26                      5                    0                    5
# 27                      6                    2                    4
# 28                      8                    2                    6
# 29                      6                    2                    4
# ...                   ...                  ...                  ...
# 192373                 40                   10                   30
# 192374                 17                   22                   -5
# 192375                  7                    8                   -1
# 192376                 70                   16                   54
# 192377                  2                    0                    2
# 192378                  2                    2                    0
# 192379                  5                    2                    3
# 192380                 12                    2                   10
# 192381                 10                    9                    1
# 192382                  7                    2                    5
# 192383                 15                    2                   13
# 192384                  8                    4                    4
# 192385                  7                    1                    6
# 192386                  0                    0                    0
# 192387                 44                    9                   35
# 192388                 37                    1                   36
# 192389                  6                    1                    5
# 192390                108                    5                  103
# 192391                  0                    0                    0
# 192392                  4                    2                    2
# 192393                  3                    1                    2
# 192394                  1                    5                   -4
# 192395                  3                    2                    1
# 192396                  0                    0                    0
# 192397                  2                    0                    2
# 192398                  2                    1                    1
# 192399                  9                    3                    6
# 192400                  2                    0                    2
# 192401                 62                    7                   55
# 192402                 26                    2                   24
#
# [192403 rows x 9 columns]

# %%
reviewer_df.describe()
# Out:
#          reviewCount      Avgrating  avg_wordcount  sum_helpful_votes  \
# count  192403.000000  192403.000000  192403.000000      192403.000000
# mean        8.779427       4.205929     102.262303          27.747930
# std         8.263942       0.650905      91.019405         174.715909
# min         5.000000       1.000000       1.000000           0.000000
# 25%         5.000000       3.843444      45.625000           1.000000
# 50%         7.000000       4.333333      74.400000           5.000000
# 75%         9.000000       4.700000     126.166667          15.000000
# max       431.000000       5.000000    2639.200000       30833.000000
#
#        sum_unhelpful_votes  overall_helpfulness
# count        192403.000000        192403.000000
# mean              5.442020            22.305910
# std              19.756926           164.755898
# min               0.000000         -2584.000000
# 25%               0.000000             0.000000
# 50%               2.000000             3.000000
# 75%               5.000000            11.000000
# max            2855.000000         30103.000000

# %%
reviewer_df.hist(column='overall_helpfulness', bins=5)
plt.savefig("vgRatings.png")

# %%
large=reviewer_df.loc[reviewer_df['reviewCount']> 430]

# %%
large

# %%
plt.boxplot(reviewer_df['reviewCount'])

# %%
reviewer_df.to_csv('reviwer_df.csv',index=False)

# %%
meanReview_yearly = data.groupby(['reviewerID', 'Year'])['overall'].mean().reset_index()
meanReview_yearly

# %%
meanReview_yearly.to_csv('yearly.csv',index=False)
